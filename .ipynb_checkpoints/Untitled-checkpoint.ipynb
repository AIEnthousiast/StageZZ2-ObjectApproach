# %%
from SNOPSolutionOutOfPlace import SNOPSOlutionOutOfPlace
from Instances import GridInstance

# %%
instance = GridInstance(n=3)

# %%
sol = SNOPSOlutionOutOfPlace(instance.get_random_strong_orientation())

# %%
sol.show()

# %%
P = sorted(sol.get_minimum_paths().values(),key= lambda x : x[0],reverse=True)values

# %%
# Out:
# [(6,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (6,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (6,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (6,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (5,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (4,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (3,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (2,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False),
#    Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='2', position=(0, 1), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='3', position=(0, 2), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='6', position=(1, 2), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='7', position=(2, 0), color='b'), endpoint_2=Node(label='4', position=(1, 0), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='9', position=(2, 2), color='b'), endpoint_2=Node(label='6', position=(1, 2), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='7', position=(2, 0), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='8', position=(2, 1), color='b'), endpoint_2=Node(label='9', position=(2, 2), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='1', position=(0, 0), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='5', position=(1, 1), color='b'), endpoint_2=Node(label='8', position=(2, 1), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='1', position=(0, 0), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='4', position=(1, 0), color='b'), endpoint_2=Node(label='5', position=(1, 1), color='b'), cost=1, blocked=False)]),
#  (1,
#   [Edge(endpoint_1=Node(label='3', position=(0, 2), color='b'), endpoint_2=Node(label='2', position=(0, 1), color='b'), cost=1, blocked=False)]),
#  (0, []),
#  (0, []),
#  (0, []),
#  (0, []),
#  (0, []),
#  (0, []),
#  (0, []),
#  (0, []),
#  (0, [])]
